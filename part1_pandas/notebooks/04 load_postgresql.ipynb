# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv('../data/processed/final_financial_kpis.csv')

# %%
df.head()
# Out:
#      company_name  financial_year  sales  expenses  operating_profit  \
# 0  20 Microns Ltd            2012  300.0     264.0              36.0
# 1  20 Microns Ltd            2013  312.0     273.0              39.0
# 2  20 Microns Ltd            2014  327.0     297.0              31.0
# 3  20 Microns Ltd            2015  356.0     326.0              30.0
# 4  20 Microns Ltd            2016  357.0     310.0              46.0
#
#    interest  depreciation  profit_before_tax  net_profit  eps_in_rs  \
# 0      16.0           7.0               16.0        11.0       3.85
# 1      18.0           8.0                8.0         5.0       1.51
# 2      24.0          11.0               -2.0        -2.0      -0.68
# 3      27.0          11.0               -3.0        -2.0      -0.74
# 4      25.0          10.0               14.0        11.0       3.11
#
#    profit_margin    opm  expense_ratio  interest_coverage  \
# 0           3.67  12.00          88.00               2.25
# ...

# %%
df.shape
# Out:
# (43910, 19)

# %%
engine = create_engine(
    'postgresql://postgres:Lakshay%405467@localhost:5432/financial_db'
)

# %%
import numpy as np
df = df.replace([np.inf,-np.inf],np.nan)

# %%
df.to_sql('company_financials',engine,if_exists='append',index=False)
# Out:
# 910
