# %%
import pandas as pd
df = pd.read_csv('../data/raw/financials.csv')
df.head(22)
# Out:
#            Unnamed: 0  Mar 2012  Mar 2013  Mar 2014  Mar 2015  Mar 2016  \
# 0               Sales    300.00    312.00    327.00    356.00    357.00
# 1            Expenses    264.00    273.00    297.00    326.00    310.00
# 2    Operating Profit     36.00     39.00     31.00     30.00     46.00
# 3               OPM %     12.00     12.00      9.00      8.00     13.00
# 4        Other Income      2.00     -5.00      2.00      4.00      4.00
# 5            Interest     16.00     18.00     24.00     27.00     25.00
# 6        Depreciation      7.00      8.00     11.00     11.00     10.00
# 7   Profit before tax     16.00      8.00     -2.00     -3.00     14.00
# 8               Tax %     29.00     37.00    -19.00     16.00     24.00
# 9          Net Profit     11.00      5.00     -2.00     -2.00     11.00
# 10          EPS in Rs      3.85      1.51     -0.68     -0.74      3.11
# 11              Sales       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df.shape
# Out:
# (49401, 113)

# %%
df['Unnamed: 0'].unique()
# Out:
# array(['Sales', 'Expenses', 'Operating Profit', 'OPM %', 'Other Income',
#        'Interest', 'Depreciation', 'Profit before tax', 'Tax %',
#        'Net Profit', 'EPS in Rs', 'Revenue', 'Financing Profit',
#        'Financing Margin %'], dtype=object)

# %%
df['company_name'].nunique()
# Out:
# 4491

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Mar 2012',
#  'Mar 2013',
#  'Mar 2014',
#  'Mar 2015',
#  'Mar 2016',
#  'Mar 2017',
#  'Mar 2018',
#  'Mar 2019',
#  'Mar 2020',
#  'Mar 2021',
#  'Mar 2022',
#  'Mar 2023',
#  'TTM',
#  'company_name',
#  '2012-03-01',
#  '2013-03-01',
#  '2014-03-01',
#  '2015-03-01',
#  '2016-03-01',
#  '2017-03-01',
#  '2018-03-01',
#  '2019-03-01',
#  '2020-03-01',
#  '2021-03-01',
#  '2022-03-01',
#  '2023-03-01',
#  'Mar 2011',
#  'Dec 2011',
#  'Dec 2012',
#  'Dec 2013',
#  'Dec 2014',
#  'Dec 2015',
#  'Dec 2016',
#  'Dec 2017',
#  'Dec 2018',
#  'Dec 2019',
#  'Dec 2020',
#  'Dec 2021',
#  'Dec 2022',
#  'Mar 2006',
#  'Mar 2007',
#  'Mar 2008',
#  'Mar 2009',
#  'Mar 2010',
#  'Jan 2023',
#  'Jun 2012',
#  'Jun 2013',
#  'Jun 2014',
#  'Jun 2015',
#  'Jun 2016',
#  'Jun 2017',
#  'Jun 2018',
#  'Jun 2019',
#  'Jun 2020',
#  'Jun 2021',
#  'Jun 2022',
#  'Jun 2023',
#  'Sep 2012',
#  'Sep 2013',
#  'Sep 2018',
#  'Sep 2011',
#  '2010-03-01',
#  '2011-03-01',
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# Mar 2012      16855
# Mar 2013      15926
# Mar 2014      14741
# Mar 2015      12757
#               ...
# 2022-09-01    49390
# 2023-09-01    49390
# Nov 2014      49392
# 2023-05-01    49390
# Dec 2010      49392
# Length: 113, dtype: int64

# %%
df['company_name'].nunique()
# Out:
# 4491

# %%
df[df['company_name'] == 'Reliance Industries Ltd']
# Out:
#               Unnamed: 0   Mar 2012   Mar 2013   Mar 2014   Mar 2015  \
# 34958              Sales  357677.00  395957.00  433521.00  374372.00
# 34959           Expenses  324501.00  362802.00  398586.00  336923.00
# 34960   Operating Profit   33176.00   33155.00   34935.00   37449.00
# 34961              OPM %       9.00       8.00       8.00      10.00
# 34962       Other Income    7526.00    7757.00    8865.00    8528.00
# 34963           Interest    2893.00    3463.00    3836.00    3316.00
# 34964       Depreciation   12401.00   11232.00   11201.00   11547.00
# 34965  Profit before tax   25408.00   26217.00   28763.00   31114.00
# 34966              Tax %      22.00      20.00      22.00      24.00
# 34967         Net Profit   19717.00   20886.00   22548.00   23640.00
# 34968          EPS in Rs      28.26      30.31      32.62      34.14
#
#         Mar 2016   Mar 2017   Mar 2018   Mar 2019  Mar 2020  ...  2017-09-01  \
# ...

# %%
pd.set_option('display.max_columns', None)
df[df['company_name'] == 'Reliance Industries Ltd']
# Out:
#               Unnamed: 0   Mar 2012   Mar 2013   Mar 2014   Mar 2015  \
# 34958              Sales  357677.00  395957.00  433521.00  374372.00
# 34959           Expenses  324501.00  362802.00  398586.00  336923.00
# 34960   Operating Profit   33176.00   33155.00   34935.00   37449.00
# 34961              OPM %       9.00       8.00       8.00      10.00
# 34962       Other Income    7526.00    7757.00    8865.00    8528.00
# 34963           Interest    2893.00    3463.00    3836.00    3316.00
# 34964       Depreciation   12401.00   11232.00   11201.00   11547.00
# 34965  Profit before tax   25408.00   26217.00   28763.00   31114.00
# 34966              Tax %      22.00      20.00      22.00      24.00
# 34967         Net Profit   19717.00   20886.00   22548.00   23640.00
# 34968          EPS in Rs      28.26      30.31      32.62      34.14
#
#         Mar 2016   Mar 2017   Mar 2018   Mar 2019  Mar 2020  Mar 2021  \
# ...
